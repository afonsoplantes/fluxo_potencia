# %%
import pySEP as psp  
  
c = psp.Circuito(sBase=100e6)
  
c.addBarra(1, 1, 1.05, 0, 0 + 0 * 1j, 0 + 0 * 1j)  
c.addBarra(2, 2, 1.00, 0, 256.6e6 + 110.2e6 * 1j, 0 + 0 * 1j)  
c.addBarra(3, 2, 1.00, 0, 138.6e6 + 45.2e6 * 1j, 0 + 0 * 1j)  
  
c.addLinha(1, 2, z_ij=0.02 + 0.04j)  
c.addLinha(1, 3, z_ij=0.01 + 0.03j)  
c.addLinha(2, 3, z_ij=0.0125 + 0.025j)  
  
c.calcular_fluxo_pot_nr(erro=0.01, show=False)  
  
c.relatorio(show_tensoes=True, show_correntes=True, show_fluxo=True)  
  
c.perdas(show=True)
  
c.plot_conv(tensao=True, ang=True)
# Out:
# =============================== Sesp: =================================
# {2: {'Pesp': -2.566, 'Qesp': -1.102}, 3: {'Pesp': -1.386, 'Qesp': -0.452}}  pu
# ========================================================================
#
#
# ============================= YBUS: ====================================
# [ 20.-50.j -10.+20.j -10.+30.j]
# [-10.+20.j  26.-52.j -16.+32.j]
# [-10.+30.j -16.+32.j  26.-62.j]
# ========================================================================
#
#
# =============================== DADOS: =================================
# Sbase =  100000000.0  VA
# Barra:  1 	{'code': 1, 'tensao': 1.05, 'ang': 0.0, 'carga': 0j, 'geracao': 0j}
# Barra:  2 	{'code': 2, 'tensao': 0.984196249741332, 'ang': -0.06039151950503535, 'carga': (2.566+1.102j), 'geracao': 0j}
# Barra:  3 	{'code': 2, 'tensao': 1.0031877730252479, 'ang': -0.049648454180214796, 'carga': (1.386+0.452j), 'geracao': 0j}
# ========================================================================
#
#
# =============================== DADOS: =================================
# Sbase =  100000000.0  VA
# Barra:  1 	{'code': 1, 'tensao': 1.05, 'ang': 0.0, 'carga': 0j, 'geracao': 0j}
# Barra:  2 	{'code': 2, 'tensao': 0.981841196460323, 'ang': -0.06114559414940125, 'carga': (2.566+1.102j), 'geracao': 0j}
# Barra:  3 	{'code': 2, 'tensao': 1.0012539887517393, 'ang': -0.04995766626194856, 'carga': (1.386+0.452j), 'geracao': 0j}
# ========================================================================
#
#
# listTensao:  [2, 3]
# listAng:  [2, 3]
#
#
# nPQ:  2
# nPV:  0
# CONVERGIU PARA UM ERRO DE  0.01  .
# CONVERGIU EM  3  ITERAÇÕES.
#
# ============================ TENSÕES: =======================================
# Barra: 	 1 	TENSÃO = 	 (1.05+0j) 	[pu]
# Barra: 	 2 	TENSÃO = 	 (0.9800000865671326-0.05999999509546221j) 	[pu]
# Barra: 	 3 	TENSÃO = 	 (1.0000000720155082-0.050000083787768435j) 	[pu]
# ===============================================================================
# ============================ CORRENTES: =======================================
# Ligação: 	 (1, 2) 	Corrente = 	 (-1.899999036237919+0.7999983177027277j) 	[pu]
# Ligação: 	 (1, 3) 	Corrente = 	 (-2.0000017934779715+0.9999970016570703j) 	[pu]
# Ligação: 	 (1, 1) 	Corrente = 	 (-3.9000008297158906+1.799995319359798j) 	[pu]
# Ligação: 	 (2, 1) 	Corrente = 	 (1.899999036237919-0.7999983177027277j) 	[pu]
# Ligação: 	 (2, 3) 	Corrente = 	 (0.6399969290202114-0.480000953424921j) 	[pu]
# Ligação: 	 (2, 2) 	Corrente = 	 (2.5399959652581305-1.2799992711276487j) 	[pu]
# Ligação: 	 (3, 1) 	Corrente = 	 (2.0000017934779715-0.9999970016570703j) 	[pu]
# Ligação: 	 (3, 2) 	Corrente = 	 (-0.6399969290202114+0.480000953424921j) 	[pu]
# Ligação: 	 (3, 3) 	Corrente = 	 (1.36000486445776-0.5199960482321493j) 	[pu]
# ===============================================================================
# ======================== Fluxo de Potência: ===================================
# Ligação: 	 (1, 2) 	Fluxo = 	 (1.9949989880498151+0.8399982335878641j) 	[pu]
# Ligação: 	 (1, 3) 	Fluxo = 	 (2.10000188315187+1.0499968517399239j) 	[pu]
# Ligação: 	 (1, 1) 	Fluxo = 	 (4.095000871201686+1.889995085327788j) 	[pu]
# Ligação: 	 (2, 1) 	Fluxo = 	 (-1.9099991151291709-0.6699984877465754j) 	[pu]
# Ligação: 	 (2, 3) 	Fluxo = 	 (-0.6559971006938187-0.4320011633064052j) 	[pu]
# Ligação: 	 (2, 2) 	Fluxo = 	 (-2.5659962158229894-1.1019996510529806j) 	[pu]
# Ligação: 	 (3, 1) 	Fluxo = 	 (-2.050001871379488-0.8999968164227768j) 	[pu]
# Ligação: 	 (3, 2) 	Fluxo = 	 (0.6639970629993702+0.4480010879175086j) 	[pu]
# Ligação: 	 (3, 3) 	Fluxo = 	 (-1.3860048083801173-0.45199572850526826j) 	[pu]
# ===============================================================================
#
#
# Perdas	= 	 (0.28599969399715697+0.6719994115390779j) 	[pu]
